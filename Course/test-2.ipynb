# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\Shayan\AppData\Local\Temp\ipykernel_21936\829968020.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
a = np.random.randint(0, 1000, (10, 10) )
print(a)
sns.displot(a)
plt.show()
# Out:
# [[898 963  13 897 177 582 300 863 272 268]
#  [320 700 980 402 574 783 183 559 621 107]
#  [149 357 640 114 477 476  54  85 484 531]
#  [403 226 821 754 722 704 844  64   9  34]
#  [846 917 210 365 319 667  56 308 309 874]
#  [ 45 544 191 753  73 869  33 728 867 693]
#  [793  28 769 259 948 963 625 956 622 618]
#  [566 391  28 903  49 732 686 557 939 302]
#  [373 977 160 575 855 772 700 340 600 142]
#  [ 14 158 534 687 499 722 212 127 839 564]]

# %% [markdown]
# **Generate a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2:**

# %%
x = np.random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 4.24420903  1.8049319   4.54208048]
#  [ 3.00185033 -1.60524453  3.43837842]]

# %%
sns.distplot(np.random.normal(size=100), hist=False)

plt.show()
# Out:
# C:\Users\Shayan\AppData\Local\Temp\ipykernel_21936\313083112.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(size=100), hist=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
def mandelbrot(h, w, maxit=20, r=2):
    """Returns an image of the Mandelbrot fractal of size (h,w)."""
    x = np.linspace(-2.5, 1.5, 4*h+1)
    y = np.linspace(-1.5, 1.5, 3*w+1)
    A, B = np.meshgrid(x, y)
    C = A + B*1j
    z = np.zeros_like(C)
    divtime = maxit + np.zeros(z.shape, dtype=int)
    for i in range(maxit):
        z = z**2 + C
        diverge = abs(z) > r                    # who is diverging
        div_now = diverge & (divtime == maxit)  # who is diverging now
        divtime[div_now] = i                    # note when
        z[diverge] = r                          # avoid diverging too much
    return divtime
plt.clf()
plt.imshow(mandelbrot(400, 400))
